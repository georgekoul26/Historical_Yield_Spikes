# %%
import os
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import alpaca_trade_api as tradeapi
from dotenv import load_dotenv

# %%
df=pd.read_csv('historical_data.csv') 
df.set_index("Date", inplace=True)
df.head()
# Out:
#               XLY    XLP    XLE    XLF    XLV    XLI    XLB    XLK    XLU  \
# Date
# 2008-01-02  32.13  28.34  79.75  28.41  34.94  38.37  41.33  26.10  41.98
# 2008-01-03  31.78  28.22  80.21  28.20  35.18  38.58  41.80  26.08  42.08
# 2008-01-04  30.78  28.04  78.01  27.39  34.83  37.60  40.74  25.07  42.30
# 2008-01-07  30.93  28.55  77.04  27.55  35.57  37.34  40.25  24.97  43.25
# 2008-01-08  30.32  28.38  76.08  26.54  35.81  36.39  39.60  24.21  43.33
#
#             10 YR
# Date
# 2008-01-02   3.91
# 2008-01-03   3.91
# 2008-01-04   3.88
# 2008-01-07   3.86
# 2008-01-08   3.86

# %%
df_10yr = df[["10 YR"]]

# %%
df_10yr.head()
# Out:
#             10 YR
# Date
# 2008-01-02   3.91
# 2008-01-03   3.91
# 2008-01-04   3.88
# 2008-01-07   3.86
# 2008-01-08   3.86

# %%
df_10yr["percent_change"]= df_10yr["10 YR"].pct_change()
df_10yr["7day"] = ((df_10yr["10 YR"]-df_10yr["10 YR"].shift(periods=7))/df_10yr["10 YR"].shift(periods=7))
df_10yr.head(20)
# Out:
# /Users/daviddivito/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/daviddivito/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             10 YR  percent_change      7day
# Date
# 2008-01-02   3.91             NaN       NaN
# 2008-01-03   3.91        0.000000       NaN
# ...

# %%
df_10yr["7day"].plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_10yr["percent_change"].plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>
